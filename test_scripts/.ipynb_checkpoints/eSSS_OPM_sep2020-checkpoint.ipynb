# %%
def load_UCL_OPM(raw_name, chan_name, json_file, pos_file):
    # Import the necessary packages
    import numpy as np
    import matplotlib.pyplot as plt
    import mne
    import pandas as pd
    import json

    # Load 1D data from .bin file
    d = np.fromfile(raw_name,'>f4')
    
    print('Data loaded as: ' + str(d.dtype))
    
    # Load tsv channels file
    tsv = pd.read_csv(chan_name,sep='\t')
    
    # Replace the channel types with a
    tsv['type'] = tsv['type'].replace('MEGMAG','mag')
    tsv['type'] = tsv['type'].replace('TRIG','stim')
    tsv['type'] = tsv['type'].replace('REF','ref_meg')
    
    # Replace Flux channels with misc
    tsv.loc[tsv.name.str.contains('Flux'), 'type'] = 'misc'
    
    # Put these into a list
    chans = tsv['name'].values.tolist()
    types = tsv['type'].values.tolist()
    
    # Open the _meg.json and extract the sampling freq
    with open(chan_json) as json_file:
        json_meg = json.load(json_file)

    Fs = json_meg['SamplingFrequency']
    
#     # Make a montage
#     pos_tsv = pd.read_csv(pos_file,sep='\t')

#     dict = {}

#     for e in np.arange(0,len(pos_tsv)):
#         dict[pos_tsv.name[e]] = np.array([pos_tsv.Px[e]/1000,pos_tsv.Py[e]/1000,pos_tsv.Pz[e]/1000])

#     montage_opm = mne.channels.make_dig_montage(ch_pos=dict,coord_frame='mri')
    
    # Create MNE info field
    inf = mne.create_info(chans, Fs, ch_types = types, verbose=None)
    
    # Reshape the 1D data into 2D based on the number of channels present
    d2 = np.reshape(d, [len(chans), int(len(d)/len(chans))],'F')
    
    # Create raw MNE object
    raw = mne.io.RawArray(d2, inf, first_samp=0, copy='auto', verbose=None)
    
    return raw

# %%
import numpy as np
import matplotlib.pyplot as plt
import mne
import pandas as pd
import json
import os.path as op
from mne.io import read_raw_fif

# %%
# %matplotlib qt

# %%
# Path to data
script_dir      = '/Users/rseymoue/Documents/GitHub/analyse_OPMEG'
data_dir        = '/Volumes/Robert T5/22_09_2020_benchmarking/'
save_dir        = '/Users/rseymoue/Documents/GitHub/opm_benchmarking_feb_2020/'

# %%
raw_name               = op.join(data_dir, 'sub-NA/', 'ses-001/','meg/','sub-NA_ses-001_task-MMF_run-001_meg.bin')
raw_emptyroom_name     = op.join(data_dir, 'sub-001/', 'ses-001/','meg/','sub-001_ses-001_task-noise_run-001_meg.bin')
chan_name              = op.join(data_dir, 'sub-NA/', 'ses-001/','meg/','sub-NA_ses-001_task-MMF_run-001_channels.tsv')
chan_json              = op.join(data_dir, 'sub-NA/', 'ses-001/','meg/','sub-NA_ses-001_task-MMF_run-001_meg.json')
pos_file               = op.join(data_dir, 'sub-NA/', 'ses-001/','meg/','sub-NA_ses-001_task-MMF_run-001_positions.tsv')

# %%
raw       = load_UCL_OPM(raw_name, chan_name, chan_json, pos_file)
raw_noise = load_UCL_OPM(raw_emptyroom_name, chan_name, chan_json, pos_file)
# Out:
# Data loaded as: >f4
# Creating RawArray with float64 data, n_channels=77, n_times=4504140
#     Range : 0 ... 4504139 =      0.000 ...   750.690 secs
# Ready.
# Data loaded as: >f4
# Creating RawArray with float64 data, n_channels=77, n_times=1080540
#     Range : 0 ... 1080539 =      0.000 ...   180.090 secs
# Ready.

# %%
raw.resample(600)
# Out:
# 1567 events found
# Event IDs: [1 2 3 4 5]
# 1457 events found
# Event IDs: [2 3 4 5]
# <RawArray | 77 x 450414 (750.7 s), ~264.8 MB, data loaded>

# %%
picks = mne.pick_types(raw.info,'mag')

# %%
raw2 = read_raw_fif('/Users/rseymoue/MMF_data_raw.fif')
raw2.resample(600)
raw_mag = raw.pick_types('mag')

raw_mag.info = raw2.info
raw_noise.info = raw2.info

raw_mag.plot_sensors(kind='3d')
# Out:
# Opening raw data file /Users/rseymoue/MMF_data_raw.fif...
# Isotrak not found
#     Range : 0 ... 4504139 =      0.000 ...   750.690 secs
# Ready.

# %%
raw_mag.info['bads'] = ['DP-RAD','DP-TAN']
raw_noise.info['bads'] = ['DP-RAD','DP-TAN']

# %%
data_ls = least_square_reference(raw_mag_600, empty_room=raw_noise)

# %%
ssp1 = mne.compute_proj_raw(raw_noise,n_mag=60)
# mne.viz.plot_projs_topomap(ssp1, colorbar=True, vlim='joint',
#                            info=raw_noise.info)
# Out:
# Not setting metadata
# Not setting metadata
# 1800 matching events found
# No baseline correction applied
# No gradiometers found. Forcing n_grad to 0
# Adding projection: axial-Raw-0.000-1800.900-PCA-01
# Adding projection: axial-Raw-0.000-1800.900-PCA-02
# Adding projection: axial-Raw-0.000-1800.900-PCA-03
# Adding projection: axial-Raw-0.000-1800.900-PCA-04
# Adding projection: axial-Raw-0.000-1800.900-PCA-05
# Adding projection: axial-Raw-0.000-1800.900-PCA-06
# Adding projection: axial-Raw-0.000-1800.900-PCA-07
# Adding projection: axial-Raw-0.000-1800.900-PCA-08
# Adding projection: axial-Raw-0.000-1800.900-PCA-09
# Adding projection: axial-Raw-0.000-1800.900-PCA-10
# Adding projection: axial-Raw-0.000-1800.900-PCA-11
# Adding projection: axial-Raw-0.000-1800.900-PCA-12
# Adding projection: axial-Raw-0.000-1800.900-PCA-13
# Adding projection: axial-Raw-0.000-1800.900-PCA-14
# Adding projection: axial-Raw-0.000-1800.900-PCA-15
# Adding projection: axial-Raw-0.000-1800.900-PCA-16
# Adding projection: axial-Raw-0.000-1800.900-PCA-17
# Adding projection: axial-Raw-0.000-1800.900-PCA-18
# Adding projection: axial-Raw-0.000-1800.900-PCA-19
# Adding projection: axial-Raw-0.000-1800.900-PCA-20
# Adding projection: axial-Raw-0.000-1800.900-PCA-21
# Adding projection: axial-Raw-0.000-1800.900-PCA-22
# Adding projection: axial-Raw-0.000-1800.900-PCA-23
# Adding projection: axial-Raw-0.000-1800.900-PCA-24
# Adding projection: axial-Raw-0.000-1800.900-PCA-25
# Adding projection: axial-Raw-0.000-1800.900-PCA-26
# Adding projection: axial-Raw-0.000-1800.900-PCA-27
# Adding projection: axial-Raw-0.000-1800.900-PCA-28
# Adding projection: axial-Raw-0.000-1800.900-PCA-29
# Adding projection: axial-Raw-0.000-1800.900-PCA-30
# Adding projection: axial-Raw-0.000-1800.900-PCA-31
# Adding projection: axial-Raw-0.000-1800.900-PCA-32
# Adding projection: axial-Raw-0.000-1800.900-PCA-33
# Adding projection: axial-Raw-0.000-1800.900-PCA-34
# Adding projection: axial-Raw-0.000-1800.900-PCA-35
# Adding projection: axial-Raw-0.000-1800.900-PCA-36
# Adding projection: axial-Raw-0.000-1800.900-PCA-37
# Adding projection: axial-Raw-0.000-1800.900-PCA-38
# Adding projection: axial-Raw-0.000-1800.900-PCA-39
# Adding projection: axial-Raw-0.000-1800.900-PCA-40
# Adding projection: axial-Raw-0.000-1800.900-PCA-41
# Adding projection: axial-Raw-0.000-1800.900-PCA-42
# Adding projection: axial-Raw-0.000-1800.900-PCA-43
# Adding projection: axial-Raw-0.000-1800.900-PCA-44
# Adding projection: axial-Raw-0.000-1800.900-PCA-45
# Adding projection: axial-Raw-0.000-1800.900-PCA-46
# Adding projection: axial-Raw-0.000-1800.900-PCA-47
# Adding projection: axial-Raw-0.000-1800.900-PCA-48
# Adding projection: axial-Raw-0.000-1800.900-PCA-49
# Adding projection: axial-Raw-0.000-1800.900-PCA-50
# Adding projection: axial-Raw-0.000-1800.900-PCA-51
# Adding projection: axial-Raw-0.000-1800.900-PCA-52
# Adding projection: axial-Raw-0.000-1800.900-PCA-53
# Adding projection: axial-Raw-0.000-1800.900-PCA-54
# Adding projection: axial-Raw-0.000-1800.900-PCA-55
# Adding projection: axial-Raw-0.000-1800.900-PCA-56
# Adding projection: axial-Raw-0.000-1800.900-PCA-57
# Adding projection: axial-Raw-0.000-1800.900-PCA-58
# Adding projection: axial-Raw-0.000-1800.900-PCA-59
# Adding projection: axial-Raw-0.000-1800.900-PCA-60

# %%
mne.channels.fix_mag_coil_types(raw_mag.info)
# Out:
# 60 of 60 magnetometer types replaced with T3.

# %%
raw_mag_sss = mne.preprocessing.maxwell_filter(raw_mag,st_duration=10.0,
                                               int_order = 5,coord_frame='meg',verbose=True)
# Out:
# Maxwell filtering raw data
#     Bad MEG channels being reconstructed: ['DP-RAD', 'DP-TAN']
#     Processing 0 gradiometers and 62 magnetometers
#     Using origin 0.0, 0.0, 0.0 mm in the meg frame (0.0, 0.0, 0.0 mm in the head frame)
#     Processing data using tSSS with st_duration=10.0
#         Using 18/50 harmonic components for    0.000  (3/35 in, 15/15 out)
#     Using loaded raw data
#     Spatiotemporal window did not fit evenly intocontiguous data segment. 0.69 seconds were lumped into the previous window.
#     Processing 75 data chunks
#         Projecting  2 intersecting tSSS components for    0.000 -    9.998 sec  (#1/75)
#         Projecting  2 intersecting tSSS components for   10.000 -   19.998 sec  (#2/75)
#         Projecting  2 intersecting tSSS components for   20.000 -   29.998 sec  (#3/75)
#         Projecting  2 intersecting tSSS components for   30.000 -   39.998 sec  (#4/75)
#         Projecting  3 intersecting tSSS components for   40.000 -   49.998 sec  (#5/75)
#         Projecting  2 intersecting tSSS components for   50.000 -   59.998 sec  (#6/75)
#         Projecting  2 intersecting tSSS components for   60.000 -   69.998 sec  (#7/75)
#         Projecting  1 intersecting tSSS component  for   70.000 -   79.998 sec  (#8/75)
#         Projecting  2 intersecting tSSS components for   80.000 -   89.998 sec  (#9/75)
#         Projecting  1 intersecting tSSS component  for   90.000 -   99.998 sec (#10/75)
#         Projecting  2 intersecting tSSS components for  100.000 -  109.998 sec (#11/75)
#         Projecting  2 intersecting tSSS components for  110.000 -  119.998 sec (#12/75)
#         Projecting  2 intersecting tSSS components for  120.000 -  129.998 sec (#13/75)
#         Projecting  2 intersecting tSSS components for  130.000 -  139.998 sec (#14/75)
#         Projecting  2 intersecting tSSS components for  140.000 -  149.998 sec (#15/75)
#         Projecting  2 intersecting tSSS components for  150.000 -  159.998 sec (#16/75)
#         Projecting  2 intersecting tSSS components for  160.000 -  169.998 sec (#17/75)
#         Projecting  2 intersecting tSSS components for  170.000 -  179.998 sec (#18/75)
#         Projecting  2 intersecting tSSS components for  180.000 -  189.998 sec (#19/75)
#         Projecting  2 intersecting tSSS components for  190.000 -  199.998 sec (#20/75)
#         Projecting  2 intersecting tSSS components for  200.000 -  209.998 sec (#21/75)
#         Projecting  2 intersecting tSSS components for  210.000 -  219.998 sec (#22/75)
#         Projecting  2 intersecting tSSS components for  220.000 -  229.998 sec (#23/75)
#         Projecting  2 intersecting tSSS components for  230.000 -  239.998 sec (#24/75)
#         Projecting  3 intersecting tSSS components for  240.000 -  249.998 sec (#25/75)
#         Projecting  2 intersecting tSSS components for  250.000 -  259.998 sec (#26/75)
#         Projecting  2 intersecting tSSS components for  260.000 -  269.998 sec (#27/75)
#         Projecting  3 intersecting tSSS components for  270.000 -  279.998 sec (#28/75)
#         Projecting  2 intersecting tSSS components for  280.000 -  289.998 sec (#29/75)
#         Projecting  2 intersecting tSSS components for  290.000 -  299.998 sec (#30/75)
#         Projecting  2 intersecting tSSS components for  300.000 -  309.998 sec (#31/75)
#         Projecting  2 intersecting tSSS components for  310.000 -  319.998 sec (#32/75)
#         Projecting  2 intersecting tSSS components for  320.000 -  329.998 sec (#33/75)
#         Projecting  2 intersecting tSSS components for  330.000 -  339.998 sec (#34/75)
#         Projecting  2 intersecting tSSS components for  340.000 -  349.998 sec (#35/75)
#         Projecting  3 intersecting tSSS components for  350.000 -  359.998 sec (#36/75)
#         Projecting  2 intersecting tSSS components for  360.000 -  369.998 sec (#37/75)
#         Projecting  2 intersecting tSSS components for  370.000 -  379.998 sec (#38/75)
#         Projecting  2 intersecting tSSS components for  380.000 -  389.998 sec (#39/75)
#         Projecting  2 intersecting tSSS components for  390.000 -  399.998 sec (#40/75)
#         Projecting  2 intersecting tSSS components for  400.000 -  409.998 sec (#41/75)
#         Projecting  2 intersecting tSSS components for  410.000 -  419.998 sec (#42/75)
#         Projecting  2 intersecting tSSS components for  420.000 -  429.998 sec (#43/75)
#         Projecting  2 intersecting tSSS components for  430.000 -  439.998 sec (#44/75)
#         Projecting  2 intersecting tSSS components for  440.000 -  449.998 sec (#45/75)
#         Projecting  2 intersecting tSSS components for  450.000 -  459.998 sec (#46/75)
#         Projecting  3 intersecting tSSS components for  460.000 -  469.998 sec (#47/75)
#         Projecting  3 intersecting tSSS components for  470.000 -  479.998 sec (#48/75)
#         Projecting  2 intersecting tSSS components for  480.000 -  489.998 sec (#49/75)
#         Projecting  2 intersecting tSSS components for  490.000 -  499.998 sec (#50/75)
#         Projecting  2 intersecting tSSS components for  500.000 -  509.998 sec (#51/75)
#         Projecting  2 intersecting tSSS components for  510.000 -  519.998 sec (#52/75)
#         Projecting  2 intersecting tSSS components for  520.000 -  529.998 sec (#53/75)
#         Projecting  2 intersecting tSSS components for  530.000 -  539.998 sec (#54/75)
#         Projecting  2 intersecting tSSS components for  540.000 -  549.998 sec (#55/75)
#         Projecting  2 intersecting tSSS components for  550.000 -  559.998 sec (#56/75)
#         Projecting  2 intersecting tSSS components for  560.000 -  569.998 sec (#57/75)
#         Projecting  2 intersecting tSSS components for  570.000 -  579.998 sec (#58/75)
#         Projecting  3 intersecting tSSS components for  580.000 -  589.998 sec (#59/75)
#         Projecting  2 intersecting tSSS components for  590.000 -  599.998 sec (#60/75)
#         Projecting  2 intersecting tSSS components for  600.000 -  609.998 sec (#61/75)
#         Projecting  3 intersecting tSSS components for  610.000 -  619.998 sec (#62/75)
#         Projecting  3 intersecting tSSS components for  620.000 -  629.998 sec (#63/75)
#         Projecting  2 intersecting tSSS components for  630.000 -  639.998 sec (#64/75)
#         Projecting  3 intersecting tSSS components for  640.000 -  649.998 sec (#65/75)
#         Projecting  3 intersecting tSSS components for  650.000 -  659.998 sec (#66/75)
#         Projecting  2 intersecting tSSS components for  660.000 -  669.998 sec (#67/75)
#         Projecting  2 intersecting tSSS components for  670.000 -  679.998 sec (#68/75)
#         Projecting  2 intersecting tSSS components for  680.000 -  689.998 sec (#69/75)
#         Projecting  2 intersecting tSSS components for  690.000 -  699.998 sec (#70/75)
#         Projecting  3 intersecting tSSS components for  700.000 -  709.998 sec (#71/75)
#         Projecting  3 intersecting tSSS components for  710.000 -  719.998 sec (#72/75)
#         Projecting  2 intersecting tSSS components for  720.000 -  729.998 sec (#73/75)
#         Projecting  2 intersecting tSSS components for  730.000 -  739.998 sec (#74/75)
#         Projecting  2 intersecting tSSS components for  740.000 -  750.688 sec (#75/75)
# [done]

# %%
# raw_mag_sss.plot(highpass=2, lowpass=100, remove_dc=True, scalings = 'auto', start=10.0,duration = 60)
raw_mag_sss.plot(highpass=0.1,scalings = 5e4, start=10.0,duration = 700,butterfly=True)
# Out:
# Setting up high-pass filter at 0.1 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 0.10 Hz: -6.02 dB

# %%
raw_mag.plot(scalings = 5e4, start=10.0,duration = 60)

# %%
raw_mag_sss.plot_psd(average=True,fmin=0.1,fmax=200,n_fft=60000)
# Out:
# Effective window size : 100.000 (s)

# %%
raw_mag_sss.info
# Out:
# <Info | 11 non-empty values
#  bads: []
#  ch_names: A6-TAN, A6-RAD, 1C-TAN, 1C-RAD, A2-TAN, A2-RAD, A9-TAN, A9-RAD, ...
#  chs: 62 MAG
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 3000.0 Hz
#  maxshield: False
#  meas_date: 1970-01-01 00:00:00 UTC
#  meas_id: 4 items (dict)
#  nchan: 62
#  proc_history: 1 item (list)
#  projs: []
#  sfreq: 6000.0 Hz
# >

# %%
raw_mag_sss = raw_mag_sss.notch_filter(np.arange(50, 251, 50),notch_widths=2)
raw_mag_sss = raw_mag_sss.notch_filter(120,notch_widths=2)
raw_mag_sss = raw_mag_sss.filter(l_freq=2, h_freq=40)
# Out:
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 3961 samples (6.602 sec)
#
# Setting up band-stop filter from 1.2e+02 - 1.2e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 118.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 118.25 Hz)
# - Upper passband edge: 121.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 121.75 Hz)
# - Filter length: 3961 samples (6.602 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 2 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 2.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 1.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 991 samples (1.652 sec)

# %%
raw_spare = load_UCL_OPM(raw_name, chan_name, chan_json, pos_file)
raw_spare.resample(600)
# Out:
# Data loaded as: >f4
# Creating RawArray with float64 data, n_channels=77, n_times=4504140
#     Range : 0 ... 4504139 =      0.000 ...   750.690 secs
# Ready.
# 1567 events found
# Event IDs: [1 2 3 4 5]
# 1457 events found
# Event IDs: [2 3 4 5]
# <RawArray | 77 x 450414 (750.7 s), ~264.8 MB, data loaded>

# %%
raw_spare.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: G2-A6-TAN, G2-A6-RAD, G2-1C-TAN, G2-1C-RAD, G2-A2-TAN, ...
#  chs: 62 MAG, 6 MISC, 8 REF_MEG, 1 STIM
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 300.0 Hz
#  meas_date: unspecified
#  nchan: 77
#  projs: []
#  sfreq: 600.0 Hz
# >

# %%
# Compute epochs
tmin, tmax, event_id = -0.2, 0.5, 5  # take right-hand somato

epochs = mne.Epochs(raw_mag_sss, events, event_id, tmin, tmax,
                    baseline=(-0.2, 0), preload=True)
# Out:
# Not setting metadata
# Not setting metadata
# 1449 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 1449 events and 421 original time points ...
# 1330 bad epochs dropped

# %%
# compute evoked
evoked = epochs.average()

# %%
evoked.plot(time_unit='s')
